# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
# 0 = head, 1 = tail
all_results = pd.DataFrame(columns = ['heads', 'tails'])

# %%
def coinToss(tosses):
    iteration_results = []
    global all_results
    for i in range(tosses):
        iteration_results.append((random.randint(0,1)))
    iteration_results = pd.DataFrame(
        {'heads' : [list(iteration_results).count(0)],
         'tails' : [list(iteration_results).count(1)]
        })
    all_results = all_results.append(iteration_results, ignore_index = True)

# %%
def iterations(number_of_iterations):
    for i in range(number_of_iterations):
        coinToss(i+1)

# %%
iterations(1000)

# %%
all_results['heads_probability'] = all_results['heads'] / (all_results['heads'] + all_results['tails'])

# %%
plt.plot(all_results[['heads_probability']], linewidth=0.5, color='#e35d51')
plt.ylabel('heads probability')
plt.xlabel('number of coin tosses')
